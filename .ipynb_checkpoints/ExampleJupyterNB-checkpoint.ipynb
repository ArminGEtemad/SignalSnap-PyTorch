# %%
from MultiSS_SpectrumConfig import SpectrumConfig, DataImportConfig
from MultiSS_SpectrumCalculaotr import SpectrumCalculator
from MultiSS_CrossConfig import CrossConfig
from MultiSS_PlotConfig import PlotConfig
from MultiSS_SpectrumPlotter import SpectrumPlotter

import numpy as np
import matplotlib.pyplot as plt

# %%
N = int(1e6)
data1 = np.sin(np.linspace(0, 50000*np.pi, N)) + 3
data2 = np.cos(np.linspace(0, 50000*np.pi, N)) + 3
data3 = np.random.rand(N)

config1 = DataImportConfig(data=data1)
config2 = DataImportConfig(data=data2)
config3 = DataImportConfig(data=data3)

# %%
sconfig = SpectrumConfig(dt=1, f_unit='Hz', backend='cpu', order_in=[1, 2], spectrum_size=1000, show_first_frame=True)
selected_data = [0, 1, 2]
cconfig = CrossConfig(cross_corr_2=[(1, 0), (0, 1), (2, 1)])
scalc = SpectrumCalculator(sconfig, cconfig, [config1, config2, config3], selected=selected_data)
scalc.calc_spec();
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
pconfig = PlotConfig(f_min=0, f_max=0.1, display_orders=None, significance=5, arcsinh_scale=(False, 0.02), plot_format=['re', 'im'])
plotter = SpectrumPlotter(sconfig, cconfig, scalc, pconfig)
plotter.display()
# Out:
# +---------------+--------------------+------------------------+
# | Dataset Index |         S1         |        Error S1        |
# +---------------+--------------------+------------------------+
# |      0.0      | 2.9999999965934756 |          0.0           |
# |      1.0      | 3.000000043283973  | 2.8190934244776145e-05 |
# |      2.0      | 0.4992290489287143 | 0.00014015955093782395 |
# +---------------+--------------------+------------------------+
# S2 Scaling Information:
# +----------------+--------------+
# | Arcsinh Scaled | Scale Factor |
# +----------------+--------------+
# |     False      |     N/A      |
# +----------------+--------------+

# %%
pconfig = PlotConfig(f_min=0, f_max=0.1, display_orders=None, significance=5, arcsinh_scale=(True, 0.02), plot_format=['re'])
plotter = SpectrumPlotter(sconfig, cconfig, scalc, pconfig)
plotter.display()
# Out:
# +---------------+---------------------+------------------------+
# | Dataset Index |         S1          |        Error S1        |
# +---------------+---------------------+------------------------+
# |      0.0      | 2.9999999965934756  |          0.0           |
# |      1.0      |  3.000000043283973  | 2.8190934244776145e-05 |
# |      2.0      | 0.49964604931294193 | 0.00012470372894313186 |
# +---------------+---------------------+------------------------+
# S2 Scaling Information:
# +----------------+--------------+
# | Arcsinh Scaled | Scale Factor |
# +----------------+--------------+
# |      True      |     0.02     |
# +----------------+--------------+

# %%
# Define the HDF5 file path
hdf5_file_path = "test_data.h5"
config1 = DataImportConfig(path=hdf5_file_path, group_key="group1", dataset="data1")

# %%
sconfig = SpectrumConfig(dt=1, f_unit='Hz', backend='cpu', order_in=[1, 2], spectrum_size=100, show_first_frame=True)
cconfig = CrossConfig(auto_corr=True, cross_corr_2=None)
scalc = SpectrumCalculator(sconfig, cconfig, [config1], selected=None)
#scalc.calc_spec();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 sconfig = SpectrumConfig(dt=1, f_unit='Hz', backend='cpu', order_in=[1, 2], spectrum_size=100, show_first_frame=True)
#       2 cconfig = CrossConfig(cross_corr_2=None)
# ----> 3 scalc = SpectrumCalculator(sconfig, cconfig, [config1], selected=None)
#
# File ~/Documents/UniWork/PhD/Codes/SignalSnap2/MultiSS_SpectrumCalculaotr.py:146, in SpectrumCalculator.__init__(self, sconfig, cconfig, diconfig_list, selected)
#     138 self.err_counter = {
#     139     **{i: {1: 0, 2: 0} for i in self.selected},
#     140     **{j: {2: 0} for j in self.cross2_selected}
#     141 }
#     142 self.n_error_estimates = {
#     143     **{i: {1: 0, 2: 0} for i in self.selected},
#     144     **{j: {2: 0} for j in self.cross2_selected}
#     145 }
# --> 146 self.validate_shapes() # crashing the program if the data are not equally long
#     149 # insurring MPS backend precision support
#     150 if self.sconfig.backend == 'mps':
#
# File ~/Documents/UniWork/PhD/Codes/SignalSnap2/MultiSS_SpectrumCalculaotr.py:164, in SpectrumCalculator.validate_shapes(self)
#     160 def validate_shapes(self):
#     161     """
#     162     making sure that all the imported data have the same size and shape
#     163     """
# --> 164     expected_shape = self.diconfig_list[self.selected[0]].data.shape[0]
#     166     for i, data_config in enumerate(self.diconfig_list):
#     167         data_shape = data_config.data.shape[0]
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
scalc.calc_spec()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 scalc.calc_spec()
#
# File ~/Documents/UniWork/PhD/Codes/SignalSnap2/MultiSS_SpectrumCalculaotr.py:421, in SpectrumCalculator.calc_spec(self)
#     418     window = torch.from_numpy(window).to(self.device)
#     420 if self.sconfig.show_first_frame:
# --> 421     self.plot_first_frames(self.selected, window_points)
#     423 data_configs = [self.diconfig_list[dataset_idx] for dataset_idx in self.selected]
#     424 for dataset_idx in self.selected:
#
# File ~/Documents/UniWork/PhD/Codes/SignalSnap2/MultiSS_SpectrumCalculaotr.py:178, in SpectrumCalculator.plot_first_frames(self, selected, window_size)
#     176 first_frame = chunk[:window_size]
#     177 t = np.arange(len(first_frame)) * self.sconfig.dt
# --> 178 axes[i].plot(t, first_frame)
#     179 axes[i].set_xlim([0, t[-1]])
#     180 axes[i].set_title(f'first frame for data {selected_idx}')
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:496, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     494     axes.xaxis.update_units(x)
#     495 if axes.yaxis is not None:
# --> 496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
#     499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axis.py:1706, in Axis.update_units(self, data)
#    1700 def update_units(self, data):
#    1701     """
#    1702     Introspect *data* for units converter and update the
#    1703     ``axis.converter`` instance if necessary. Return *True*
#    1704     if *data* is registered for unit conversion.
#    1705     """
# -> 1706     converter = munits.registry.get_converter(data)
#    1707     if converter is None:
#    1708         return False
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/units.py:183, in Registry.get_converter(self, x)
#     181         pass
#     182 try:  # If cache lookup fails, look up based on first element...
# --> 183     first = cbook._safe_first_finite(x)
#     184 except (TypeError, StopIteration):
#     185     pass
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/cbook.py:1729, in _safe_first_finite(obj, skip_nonfinite)
#    1726     raise RuntimeError("matplotlib does not "
#    1727                        "support generators as input")
#    1728 else:
# -> 1729     for val in obj:
#    1730         if safe_isfinite(val):
#    1731             return val
#
# NotImplementedError: memoryview: unsupported format <d
